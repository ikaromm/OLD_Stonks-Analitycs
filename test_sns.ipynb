# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("csv/data.csv", sep=";", encoding="utf-8")
figura = plt.figure(figsize=(15,20))
eixo = figura.gca()
dataset.hist(ax = eixo);
# Out:
# /tmp/ipykernel_93755/3069081105.py:4: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   dataset.hist(ax = eixo);

# %%
dataset.drop(columns = ["Empresa"], inplace= True)
plt.figure(figsize=(30,50))
sns.heatmap(dataset.corr(), annot=True, cbar=False);
